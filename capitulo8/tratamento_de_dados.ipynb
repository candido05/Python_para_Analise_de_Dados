# %% [markdown]
# # Capítulo 8
#
# ## _Indexação hierárquica_

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
data = pd.Series(np.random.randn(9), 
                 index=[['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'],
                        [1, 2, 3, 1, 3, 1, 2, 2, 3]])
data
# Out:
# a  1    0.843774
#    2    1.107637
#    3   -0.110960
# b  1    0.887790
#    3   -0.605383
# c  1    0.818270
#    2    0.857708
# d  2    0.672118
#    3    1.051707
# dtype: float64

# %%
data.index
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('a', 3),
#             ('b', 1),
#             ('b', 3),
#             ('c', 1),
#             ('c', 2),
#             ('d', 2),
#             ('d', 3)],
#            )

# %%
data['b']
# Out:
# 1    0.887790
# 3   -0.605383
# dtype: float64

# %%
data['b':'c']
# Out:
# b  1    0.887790
#    3   -0.605383
# c  1    0.818270
#    2    0.857708
# dtype: float64

# %%
data.loc[['b', 'd']]
# Out:
# b  1    0.887790
#    3   -0.605383
# d  2    0.672118
#    3    1.051707
# dtype: float64

# %%
data.loc[:,2]
# Out:
# a    1.107637
# c    0.857708
# d    0.672118
# dtype: float64

# %%
data.unstack()
# Out:
#           1         2         3
# a  0.843774  1.107637 -0.110960
# b  0.887790       NaN -0.605383
# c  0.818270  0.857708       NaN
# d       NaN  0.672118  1.051707

# %%
data.unstack().stack()
# Out:
# a  1    0.843774
#    2    1.107637
#    3   -0.110960
# b  1    0.887790
#    3   -0.605383
# c  1    0.818270
#    2    0.857708
# d  2    0.672118
#    3    1.051707
# dtype: float64

# %%
frame = pd.DataFrame(np.arange(12).reshape((4,3)), 
                     index=[['a', 'a', 'b', 'b'], [1, 2, 1, 2]],
                     columns=[['Ohio', 'Ohio', 'Colocaro'],
                              ['Green', 'Red', 'Green']])
frame
# Out:
#      Ohio     Colocaro
#     Green Red    Green
# a 1     0   1        2
#   2     3   4        5
# b 1     6   7        8
#   2     9  10       11

# %%
frame.index.names = ['key1', 'key2']
frame.columns.names = ['state', 'color']
frame
# Out:
# state      Ohio     Colocaro
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
frame['Ohio']
# Out:
# color      Green  Red
# key1 key2
# a    1         0    1
#      2         3    4
# b    1         6    7
#      2         9   10

# %%
frame.index.nlevels
# Out:
# 2

# %% [markdown]
# - Reorganizando e ordenando nívies

# %%
frame.swaplevel('key1', 'key2')
# Out:
# state      Ohio     Colocaro
# color     Green Red    Green
# key2 key1
# 1    a        0   1        2
# 2    a        3   4        5
# 1    b        6   7        8
# 2    b        9  10       11

# %%
frame.sort_index(level=1)
# level=1 -> colunas
# level=0 -> index
# Out:
# state      Ohio     Colocaro
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
# b    1        6   7        8
# a    2        3   4        5
# b    2        9  10       11

# %%
frame.swaplevel(0, 1).sort_index(level=0)
# Out:
# state      Ohio     Colocaro
# color     Green Red    Green
# key2 key1
# 1    a        0   1        2
#      b        6   7        8
# 2    a        3   4        5
#      b        9  10       11

# %% [markdown]
# - Estatística de resumo por nível

# %%
frame.groupby(level='key2').sum()
# Out:
# state  Ohio     Colocaro
# color Green Red    Green
# key2
# 1         6   8       10
# 2        12  14       16

# %%
frame.groupby(level='color', axis=1).sum()
# Out:
# color      Green  Red
# key1 key2
# a    1         2    1
#      2         8    4
# b    1        14    7
#      2        20   10

# %% [markdown]
# - Indexando com as colunas de um DataFrame

# %%
frame = pd.DataFrame({'a': range(7), 'b': range(7, 0, -1),
                      'c': ['one', 'one', 'one', 'two', 'two', 'two', 'two'],
                      'd': [0, 1, 2, 0, 1, 2, 3]})

frame
# Out:
#    a  b    c  d
# 0  0  7  one  0
# 1  1  6  one  1
# 2  2  5  one  2
# 3  3  4  two  0
# 4  4  3  two  1
# 5  5  2  two  2
# 6  6  1  two  3

# %%
frame2 = frame.set_index(['c', 'd'])
frame2
# Out:
#        a  b
# c   d
# one 0  0  7
#     1  1  6
#     2  2  5
# two 0  3  4
#     1  4  3
#     2  5  2
#     3  6  1

# %%
frame.set_index(['c', 'd'], drop=False)
# Out:
#        a  b    c  d
# c   d
# one 0  0  7  one  0
#     1  1  6  one  1
#     2  2  5  one  2
# two 0  3  4  two  0
#     1  4  3  two  1
#     2  5  2  two  2
#     3  6  1  two  3

# %%
frame2.reset_index()
# Out:
#      c  d  a  b
# 0  one  0  0  7
# 1  one  1  1  6
# 2  one  2  2  5
# 3  two  0  3  4
# 4  two  1  4  3
# 5  two  2  5  2
# 6  two  3  6  1

# %% [markdown]
# ## _Combinando e mesclando conjunto de dados_

# %% [markdown]
# - Junções no DataFrame no estilo de banco de dados

# %%
df1 = pd.DataFrame({'key': list('bbacaab'),
                    'data1': range(7)})
df2 = pd.DataFrame({'key': list('abd'), 
                    'data2': range(3)})

# junção many-to-one
pd.merge(df1, df2)
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0

# %%
pd.merge(df1, df2, on='key')
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0

# %%
df3 = pd.DataFrame({'Lkey': list('bbacaab'),
                    'data1': range(7)})
df4 = pd.DataFrame({'Rkey': list('abd'), 
                    'data2': range(3)})

pd.merge(df3, df4, left_on='Lkey', right_on='Rkey')
# Out:
#   Lkey  data1 Rkey  data2
# 0    b      0    b      1
# 1    b      1    b      1
# 2    b      6    b      1
# 3    a      2    a      0
# 4    a      4    a      0
# 5    a      5    a      0

# %%
pd.merge(df1, df2, how='outer')
# Out:
#   key  data1  data2
# 0   b    0.0    1.0
# 1   b    1.0    1.0
# 2   b    6.0    1.0
# 3   a    2.0    0.0
# 4   a    4.0    0.0
# 5   a    5.0    0.0
# 6   c    3.0    NaN
# 7   d    NaN    2.0

# %%
#merge meny-to-meny
df1 = pd.DataFrame({'key': list('bbacab'),
                    'data1': range(6)})
df2 = pd.DataFrame({'key': list('ababd'), 
                    'data2': range(5)})

pd.merge(df1, df2, on='key', how='left')
# Out:
#    key  data1  data2
# 0    b      0    1.0
# 1    b      0    3.0
# 2    b      1    1.0
# 3    b      1    3.0
# 4    a      2    0.0
# 5    a      2    2.0
# 6    c      3    NaN
# 7    a      4    0.0
# 8    a      4    2.0
# 9    b      5    1.0
# 10   b      5    3.0

# %%
pd.merge(df1, df2, how='inner')
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      0      3
# 2   b      1      1
# 3   b      1      3
# 4   b      5      1
# 5   b      5      3
# 6   a      2      0
# 7   a      2      2
# 8   a      4      0
# 9   a      4      2

# %%
left = pd.DataFrame({"key1": ["foo", "foo", "bar"],
                     "key2": ["one", "two", "one"],
                     "lval": pd.Series([1, 2, 3])})

right = pd.DataFrame({"key1": ["foo", "foo", "bar", "bar"],
                      "key2": ["one", "one", "one", "two"],
                      "rval": pd.Series([4, 5, 6, 7])})

pd.merge(left, right, on=['key1', 'key2'], how='outer')
# Out:
#   key1 key2  lval  rval
# 0  foo  one   1.0   4.0
# 1  foo  one   1.0   5.0
# 2  foo  two   2.0   NaN
# 3  bar  one   3.0   6.0
# 4  bar  two   NaN   7.0

# %%
pd.merge(left, right, on='key1')
# Out:
#   key1 key2_x  lval key2_y  rval
# 0  foo    one     1    one     4
# 1  foo    one     1    one     5
# 2  foo    two     2    one     4
# 3  foo    two     2    one     5
# 4  bar    one     3    one     6
# 5  bar    one     3    two     7

# %%
pd.merge(left, right, on='key1', suffixes=('_left', '_right'))
# Out:
#   key1 key2_left  lval key2_right  rval
# 0  foo       one     1        one     4
# 1  foo       one     1        one     5
# 2  foo       two     2        one     4
# 3  foo       two     2        one     5
# 4  bar       one     3        one     6
# 5  bar       one     3        two     7

# %% [markdown]
# - Fazendo merge com base no índice

# %%
left1 = pd.DataFrame({'key': list('abaabc'), 
                    'value': range(6)})

right1 = pd.DataFrame({'group_val': [3.5, 7]}, index=['a', 'b'])

pd.merge(left1, right1, left_on='key', right_index=True)
# Out:
#   key  value  group_val
# 0   a      0        3.5
# 2   a      2        3.5
# 3   a      3        3.5
# 1   b      1        7.0
# 4   b      4        7.0

# %%
pd.merge(left1, right1, left_on='key', right_index=True, how='outer')
# Out:
#   key  value  group_val
# 0   a      0        3.5
# 2   a      2        3.5
# 3   a      3        3.5
# 1   b      1        7.0
# 4   b      4        7.0
# 5   c      5        NaN

# %%
lefth = pd.DataFrame({"key1": ["Ohio", "Ohio", "Ohio",
                               "Nevada", "Nevada"],
                      "key2": [2000, 2001, 2002, 2001, 2002],
                      "data": np.arange(5.)})

righth = pd.DataFrame(np.arange(12).reshape((6,2)),
                      index=[['Nevada', 'Nevada', 'Ohio', 'Ohio', 'Ohio', 'Ohio'],
                             [2001, 2000, 2000, 2000, 2001, 2002]],
                      columns=['event1', 'event2'])

pd.merge(lefth, righth, left_on=['key1', 'key2'], right_index=True)
# Out:
#      key1  key2  data  event1  event2
# 0    Ohio  2000   0.0       4       5
# 0    Ohio  2000   0.0       6       7
# 1    Ohio  2001   1.0       8       9
# 2    Ohio  2002   2.0      10      11
# 3  Nevada  2001   3.0       0       1

# %%
pd.merge(lefth, righth, left_on=['key1', 'key2'], right_index=True, how='outer')
# Out:
#      key1  key2  data  event1  event2
# 0    Ohio  2000   0.0     4.0     5.0
# 0    Ohio  2000   0.0     6.0     7.0
# 1    Ohio  2001   1.0     8.0     9.0
# 2    Ohio  2002   2.0    10.0    11.0
# 3  Nevada  2001   3.0     0.0     1.0
# 4  Nevada  2002   4.0     NaN     NaN
# 4  Nevada  2000   NaN     2.0     3.0

# %%
left2 = pd.DataFrame([[1, 2], [3, 4], [5, 6]],
                     index=['a', 'c', 'e'],
                     columns=['Ohio', 'Nevada'])

right2 = pd.DataFrame([[7, 8], [9, 10], [11, 12], [13, 14]],
                      index=['b', 'c', 'd', 'e'],
                      columns=['Missouri', 'Alabama'])

pd.merge(left2, right2, how='outer', left_index=True, right_index=True)
# Out:
#    Ohio  Nevada  Missouri  Alabama
# a   1.0     2.0       NaN      NaN
# b   NaN     NaN       7.0      8.0
# c   3.0     4.0       9.0     10.0
# d   NaN     NaN      11.0     12.0
# e   5.0     6.0      13.0     14.0

# %%
left2.join(right2, how='outer')
# Out:
#    Ohio  Nevada  Missouri  Alabama
# a   1.0     2.0       NaN      NaN
# b   NaN     NaN       7.0      8.0
# c   3.0     4.0       9.0     10.0
# d   NaN     NaN      11.0     12.0
# e   5.0     6.0      13.0     14.0

# %%
left1.join(right1, on='key')
# Out:
#   key  value  group_val
# 0   a      0        3.5
# 1   b      1        7.0
# 2   a      2        3.5
# 3   a      3        3.5
# 4   b      4        7.0
# 5   c      5        NaN

# %%
another = pd.DataFrame([[7, 8], [9, 10], [11, 12], [16, 17]],
                       index=['a', 'c', 'e', 'f'],
                       columns=['New York', 'Oregon'])

left2.join([right2, another])
# Out:
#    Ohio  Nevada  Missouri  Alabama  New York  Oregon
# a   1.0     2.0       NaN      NaN       7.0     8.0
# c   3.0     4.0       9.0     10.0       9.0    10.0
# e   5.0     6.0      13.0     14.0      11.0    12.0

# %%
left2.join([right2, another], how='outer')
# Out:
#    Ohio  Nevada  Missouri  Alabama  New York  Oregon
# a   1.0     2.0       NaN      NaN       7.0     8.0
# c   3.0     4.0       9.0     10.0       9.0    10.0
# e   5.0     6.0      13.0     14.0      11.0    12.0
# b   NaN     NaN       7.0      8.0       NaN     NaN
# d   NaN     NaN      11.0     12.0       NaN     NaN
# f   NaN     NaN       NaN      NaN      16.0    17.0

# %%
mergex = pd.merge(left2, right2, left_index=True, right_index=True, how='outer')
pd.merge(mergex, another, left_index=True, right_index=True, how='outer')
# Out:
#    Ohio  Nevada  Missouri  Alabama  New York  Oregon
# a   1.0     2.0       NaN      NaN       7.0     8.0
# b   NaN     NaN       7.0      8.0       NaN     NaN
# c   3.0     4.0       9.0     10.0       9.0    10.0
# d   NaN     NaN      11.0     12.0       NaN     NaN
# e   5.0     6.0      13.0     14.0      11.0    12.0
# f   NaN     NaN       NaN      NaN      16.0    17.0

# %% [markdown]
# - Concatenando ao longo de um eixo

# %%
arr = np.arange(12).reshape((3,4))
np.concatenate([arr, arr], axis=1)
# Out:
# array([[ 0,  1,  2,  3,  0,  1,  2,  3],
#        [ 4,  5,  6,  7,  4,  5,  6,  7],
#        [ 8,  9, 10, 11,  8,  9, 10, 11]])

# %%
s1 = pd.Series([0, 1], index=['a', 'b'])
s2 = pd.Series([2, 3, 4], index=['c', 'd', 'e'])
s3 = pd.Series([5, 6], index=['f', 'g'])

pd.concat([s1, s2, s3])
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# f    5
# g    6
# dtype: int64

# %%
#gerando um DataFrame usando axix=1
pd.concat([s1, s2, s3], axis=1)
# Out:
#      0    1    2
# a  0.0  NaN  NaN
# b  1.0  NaN  NaN
# c  NaN  2.0  NaN
# d  NaN  3.0  NaN
# e  NaN  4.0  NaN
# f  NaN  NaN  5.0
# g  NaN  NaN  6.0

# %%
s4 = pd.concat([s1, s3])
pd.concat([s1, s4], axis=1)
# Out:
#      0  1
# a  0.0  0
# b  1.0  1
# f  NaN  5
# g  NaN  6

# %%
pd.concat([s1, s4], axis=1, join='inner')
# Out:
#    0  1
# a  0  0
# b  1  1

# %%
result = pd.concat([s1, s1, s3], keys=["one", "two", "three"], join='outer')
result
result.unstack()
# Out:
#          a    b    f    g
# one    0.0  1.0  NaN  NaN
# two    0.0  1.0  NaN  NaN
# three  NaN  NaN  5.0  6.0

# %%
#com axix=1 os keys viram cabeçaçhos das colunas
pd.concat([s1, s1, s3], keys=["one", "two", "three"], axis=1, join='outer')
# Out:
#    one  two  three
# a  0.0  0.0    NaN
# b  1.0  1.0    NaN
# f  NaN  NaN    5.0
# g  NaN  NaN    6.0

# %%
df1 = pd.DataFrame(np.arange(6).reshape((3,2)),
                   index=['a', 'b', 'c'],
                   columns=['one', 'two'])

df2 = pd.DataFrame(5 + np.arange(4).reshape((2,2)),
                   index=['a', 'c'],
                   columns=['three', 'four'])

pd.concat([df1, df2], axis=1, keys=['level1', 'level2'])
# Out:
#   level1     level2
#      one two  three four
# a      0   1    5.0  6.0
# b      2   3    NaN  NaN
# c      4   5    7.0  8.0

# %%
pd.concat({'leve1': df1, 'level2': df2}, axis=1)
# Out:
#   leve1     level2
#     one two  three four
# a     0   1    5.0  6.0
# b     2   3    NaN  NaN
# c     4   5    7.0  8.0

# %%
pd.concat([df1, df2], axis=1, keys=['level1', 'level2'], names=['upper', 'lower'])
# Out:
# upper level1     level2
# lower    one two  three four
# a          0   1    5.0  6.0
# b          2   3    NaN  NaN
# c          4   5    7.0  8.0

# %%
df1 = pd.DataFrame(np.random.randn(3, 4), columns=list('abcd'))
df2 = pd.DataFrame(np.random.randn(2, 3), columns=list('bda'))

pd.concat([df1, df2], ignore_index=True)
# Out:
#           a         b         c         d
# 0  0.611089  0.065181  1.093028  0.124954
# 1  0.522975  0.681298  0.535547  0.740756
# 2 -1.116964 -0.971876 -0.227522 -0.433392
# 3 -0.899379 -1.295369       NaN -0.106782
# 4 -1.602178 -1.855777       NaN  1.396936

# %% [markdown]
# - Combinando dados com sobreposição

# %%
a = pd.DataFrame([np.nan, 2.5, 0, 3.5, 4.5, np.nan],
                 index=list('fedcba'))
b = pd.DataFrame([0, np.nan, 2, np.nan, np.nan, 5],
                 index=list('abcdef'))

np.where(pd.isnull(a), b, a)
# Out:
# array([[0. ],
#        [2.5],
#        [0. ],
#        [3.5],
#        [4.5],
#        [5. ]])

# %%
df1 = pd.DataFrame({"a": [1., np.nan, 5., np.nan],
                    "b": [np.nan, 2., np.nan, 6.],
                    "c": range(2, 18, 4)})
df2 = pd.DataFrame({"a": [5., 4., np.nan, 3., 7.],
                    "b": [np.nan, 3., 4., 6., 8.]})

df1.combine_first(df2)
# Out:
#      a    b     c
# 0  1.0  NaN   2.0
# 1  4.0  2.0   6.0
# 2  5.0  4.0  10.0
# 3  3.0  6.0  14.0
# 4  7.0  8.0   NaN

# %% [markdown]
# ## Reformatação e pivotamento
#
# - Reformatação com indexação hierárquica

# %%
data = pd.DataFrame(np.arange(6).reshape((2,3)),
                    index=pd.Index(['Ohio', 'Colorado'], name='state'),
                    columns=pd.Index(['one', 'two', 'three'], name='number'))

data
# Out:
# number    one  two  three
# state
# Ohio        0    1      2
# Colorado    3    4      5

# %%
result = data.stack()
result
# Out:
# state     number
# Ohio      one       0
#           two       1
#           three     2
# Colorado  one       3
#           two       4
#           three     5
# dtype: int32

# %%
result.unstack()
# Out:
# number    one  two  three
# state
# Ohio        0    1      2
# Colorado    3    4      5

# %%
result.unstack('state')
# Out:
# state   Ohio  Colorado
# number
# one        0         3
# two        1         4
# three      2         5

# %%
s1 = pd.Series([0, 1, 2, 3], index=list('abcd'))
s2 = pd.Series([4, 5, 6], index=list('cde'))
data2 = pd.concat([s1, s2], keys=['one', 'two'])
data2
# Out:
# one  a    0
#      b    1
#      c    2
#      d    3
# two  c    4
#      d    5
#      e    6
# dtype: int64

# %%
data2.unstack()
# Out:
#        a    b    c    d    e
# one  0.0  1.0  2.0  3.0  NaN
# two  NaN  NaN  4.0  5.0  6.0

# %%
data2.unstack().stack(dropna=False)
# Out:
# one  a    0.0
#      b    1.0
#      c    2.0
#      d    3.0
#      e    NaN
# two  a    NaN
#      b    NaN
#      c    4.0
#      d    5.0
#      e    6.0
# dtype: float64

# %%
df = pd.DataFrame({'left': result, 'right': result + 5},
                  columns=pd.Index(['left', 'right'], name='side'))
df
# Out:
# side             left  right
# state    number
# Ohio     one        0      5
#          two        1      6
#          three      2      7
# Colorado one        3      8
#          two        4      9
#          three      5     10

# %%
df.unstack('state')
# Out:
# side   left          right
# state  Ohio Colorado  Ohio Colorado
# number
# one       0        3     5        8
# two       1        4     6        9
# three     2        5     7       10

# %%
df.unstack('state').stack('side')
# Out:
# state         Colorado  Ohio
# number side
# one    left          3     0
#        right         8     5
# two    left          4     1
#        right         9     6
# three  left          5     2
#        right        10     7

# %% [markdown]
# - Fazendo o pivoteamento de um formato "longo" para um formato "largo"

# %%
data = pd.read_csv("exemplos/macrodata.csv")
data = data.loc[:, ["year", "quarter", "realgdp", "infl", "unemp"]]
data.head()
# Out:
#    year  quarter   realgdp  infl  unemp
# 0  1959        1  2710.349  0.00    5.8
# 1  1959        2  2778.801  2.34    5.1
# 2  1959        3  2775.488  2.74    5.3
# 3  1959        4  2785.204  0.27    5.6
# 4  1960        1  2847.699  2.31    5.2

# %%
periods = pd.PeriodIndex(year=data.pop("year"),
                         quarter=data.pop("quarter"),
                         name="date")
periods
data.index = periods.to_timestamp("D")
data.head()
# Out:
#              realgdp  infl  unemp
# date
# 1959-01-01  2710.349  0.00    5.8
# 1959-04-01  2778.801  2.34    5.1
# 1959-07-01  2775.488  2.74    5.3
# 1959-10-01  2785.204  0.27    5.6
# 1960-01-01  2847.699  2.31    5.2

# %%
data = data.reindex(columns=["realgdp", "infl", "unemp"])
data.columns.name = "item"
data.head()
# Out:
# item         realgdp  infl  unemp
# date
# 1959-01-01  2710.349  0.00    5.8
# 1959-04-01  2778.801  2.34    5.1
# 1959-07-01  2775.488  2.74    5.3
# 1959-10-01  2785.204  0.27    5.6
# 1960-01-01  2847.699  2.31    5.2

# %%
long_data = (data.stack()
             .reset_index()
             .rename(columns={0: "value"}))
long_data[:10]
# Out:
#         date     item     value
# 0 1959-01-01  realgdp  2710.349
# 1 1959-01-01     infl     0.000
# 2 1959-01-01    unemp     5.800
# 3 1959-04-01  realgdp  2778.801
# 4 1959-04-01     infl     2.340
# 5 1959-04-01    unemp     5.100
# 6 1959-07-01  realgdp  2775.488
# 7 1959-07-01     infl     2.740
# 8 1959-07-01    unemp     5.300
# 9 1959-10-01  realgdp  2785.204

# %%
pivoted = long_data.pivot(index="date", columns="item",
                          values="value")
pivoted
# Out:
# item        infl    realgdp  unemp
# date
# 1959-01-01  0.00   2710.349    5.8
# 1959-04-01  2.34   2778.801    5.1
# 1959-07-01  2.74   2775.488    5.3
# 1959-10-01  0.27   2785.204    5.6
# 1960-01-01  2.31   2847.699    5.2
# ...          ...        ...    ...
# 2008-07-01 -3.16  13324.600    6.0
# 2008-10-01 -8.79  13141.920    6.9
# 2009-01-01  0.94  12925.410    8.1
# 2009-04-01  3.37  12901.504    9.2
# 2009-07-01  3.56  12990.341    9.6
#
# [203 rows x 3 columns]

# %%
long_data['value2'] = np.random.randn(len(long_data))
long_data[:10]
# Out:
#         date     item     value    value2
# 0 1959-01-01  realgdp  2710.349 -2.475593
# 1 1959-01-01     infl     0.000 -0.189826
# 2 1959-01-01    unemp     5.800  1.190866
# 3 1959-04-01  realgdp  2778.801  1.831912
# 4 1959-04-01     infl     2.340  1.049584
# 5 1959-04-01    unemp     5.100 -1.740394
# 6 1959-07-01  realgdp  2775.488 -0.143758
# 7 1959-07-01     infl     2.740 -0.837430
# 8 1959-07-01    unemp     5.300  0.279678
# 9 1959-10-01  realgdp  2785.204 -0.515219

# %%
pivoted = long_data.pivot(index='date', columns='item')
pivoted[:5]
# Out:
#            value                    value2
# item        infl   realgdp unemp      infl   realgdp     unemp
# date
# 1959-01-01  0.00  2710.349   5.8 -0.189826 -2.475593  1.190866
# 1959-04-01  2.34  2778.801   5.1  1.049584  1.831912 -1.740394
# 1959-07-01  2.74  2775.488   5.3 -0.837430 -0.143758  0.279678
# 1959-10-01  0.27  2785.204   5.6  1.155448 -0.515219 -0.119903
# 1960-01-01  2.31  2847.699   5.2  0.612015  0.079067  0.456827

# %%
pivoted['value'][:5]
# Out:
# item        infl   realgdp  unemp
# date
# 1959-01-01  0.00  2710.349    5.8
# 1959-04-01  2.34  2778.801    5.1
# 1959-07-01  2.74  2775.488    5.3
# 1959-10-01  0.27  2785.204    5.6
# 1960-01-01  2.31  2847.699    5.2

# %% [markdown]
# - Pivoteamento do formato "largo" para o formato "longo"

# %%
df = pd.DataFrame({'key': ['foo', 'bar', 'baz'],
                   'A': [1, 2, 3],
                   'B': [4, 5, 6],
                   'C': [7, 8, 9]})

df
# Out:
#    key  A  B  C
# 0  foo  1  4  7
# 1  bar  2  5  8
# 2  baz  3  6  9

# %%
melted = pd.melt(df, ['key'])
melted
# Out:
#    key variable  value
# 0  foo        A      1
# 1  bar        A      2
# 2  baz        A      3
# 3  foo        B      4
# 4  bar        B      5
# 5  baz        B      6
# 6  foo        C      7
# 7  bar        C      8
# 8  baz        C      9

# %%
reshaped = melted.pivot(index='key', columns='variable', values='value')
reshaped
# Out:
# variable  A  B  C
# key
# bar       2  5  8
# baz       3  6  9
# foo       1  4  7

# %%
reshaped.reset_index()
# Out:
# variable  key  A  B  C
# 0         bar  2  5  8
# 1         baz  3  6  9
# 2         foo  1  4  7

# %%
pd.melt(df, id_vars="key", value_vars=["A", "B"])
# Out:
#    key variable  value
# 0  foo        A      1
# 1  bar        A      2
# 2  baz        A      3
# 3  foo        B      4
# 4  bar        B      5
# 5  baz        B      6

# %%
pd.melt(df, value_vars=["A", "B", "C"])
# Out:
#   variable  value
# 0        A      1
# 1        A      2
# 2        A      3
# 3        B      4
# 4        B      5
# 5        B      6
# 6        C      7
# 7        C      8
# 8        C      9

# %%
pd.melt(df, value_vars=["key", "A", "B"])
# Out:
#   variable value
# 0      key   foo
# 1      key   bar
# 2      key   baz
# 3        A     1
# 4        A     2
# 5        A     3
# 6        B     4
# 7        B     5
# 8        B     6
