# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
#Simulação de passeios aleatórios

#Implementação em Python puro
position = 0
walk = [position]
steps = 1000

for i in range(steps):
    step = 1 if random.randint(0, 1) else -1
    position += step
    walk.append(position)
    
plt.plot(walk[:1000])

# %%
#Uso de bibliotecas de vetorização de arrays e cálculos estatísticos
nsteps = 1000
draws = np.random.randint(0, 2, size=nsteps)
steps = np.where(draws > 0, 1, -1)
walk = steps.cumsum()

plt.plot(walk[:1000])

print(walk.min())
print(walk.max())
# Out:
# -54
# 12

# %%
#Simulando vários passeios aleatórios de uma só vez
nwalks = 5000
nsteps = 1000
draws = np.random.randint(0, 2, size=(nwalks, nsteps))
steps = np.where(draws > 0, 1, -1)
walks = steps.cumsum(1)

print(walks.max())
print(walks.min())

#cálculo entre os valores 30 e -30
hits = (np.abs(walks) >= 30).any(1)
print(hits.sum())
# Out:
# 146
# -108
# 3366
