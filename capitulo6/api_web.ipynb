# %%
import pandas as pd
import requests

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
data[0]['title']
# Out:
# 'CI: Fix weekly cache cleanup job'

# %%
inssues = pd.DataFrame(data, columns=['number', 'title', 'labels', 'state'])
inssues
# Out:
#     number                                              title  \
# 0    54067                   CI: Fix weekly cache cleanup job
# 1    54066                            Simplify pandas footer
# 2    54065  PERF: `agg` is an order of magnitude slower wi...
# 3    54064                      DOC: constant check in series
# 4    54063  BUG: creating column with ArrowDtype using pya...
# 5    54062  BUG: repr of DataFrame fails when using ArrowD...
# 6    54061  DEPR: deprecate codes T and L in _attrname_to_...
# 7    54060                          DOC: Add security policy.
# 8    54059  DEV: Error in `main` branch when subtracting a...
# 9    54058                           REF: share block methods
# 10   54057  QST: pandas.DataFrame() converts pyarrow.array...
# 11   54056  DEV: Missing a space in a warning message for ...
# 12   54055  BUG: In development version, `pd.merge` with `...
# 13   54052                      BLD: Shrink sdist/wheel sizes
# ...
